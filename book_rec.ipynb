# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv('book_rec/Books.csv',encoding="latin-1")
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_12992\3496349694.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('book_rec/Books.csv',encoding="latin-1")

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books['Image-URL-L'].iloc[5]
# Out:
# 'http://images.amazon.com/images/P/0399135782.01.LZZZZZZZ.jpg'

# %%
books = books[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher']]

# %%
books.rename(columns={'ISBN':'isbn','Book-Title':'title','Book-Author':'author', 'Year-Of-Publication':'year','Publisher':'publisher'}, inplace=True)
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_12992\114720982.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books.rename(columns={'ISBN':'isbn','Book-Title':'title','Book-Author':'author', 'Year-Of-Publication':'year','Publisher':'publisher'}, inplace=True)

# %%
books
# Out:
#               isbn                                              title  \
# 0       0195153448                                Classical Mythology
# 1       0002005018                                       Clara Callan
# 2       0060973129                               Decision in Normandy
# 3       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4       0393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271355  0440400988                         There's a Bat in Bunk Five
# 271356  0525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358  0192126040                        Republic (World's Classics)
# 271359  0767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                       author  year  \
# 0         Mark P. O. Morford  2002
# 1       Richard Bruce Wright  2001
# ...

# %%
users = pd.read_csv('book_rec/Users.csv',encoding="latin-1")

# %%
users
# Out:
#         User-ID                            Location   Age
# 0             1                  nyc, new york, usa   NaN
# 1             2           stockton, california, usa  18.0
# 2             3     moscow, yukon territory, russia   NaN
# 3             4           porto, v.n.gaia, portugal  17.0
# 4             5  farnborough, hants, united kingdom   NaN
# ...         ...                                 ...   ...
# 278853   278854               portland, oregon, usa   NaN
# 278854   278855  tacoma, washington, united kingdom  50.0
# 278855   278856           brampton, ontario, canada   NaN
# 278856   278857           knoxville, tennessee, usa   NaN
# 278857   278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
users.rename(columns={'User-ID':'id','Location':'location','Age':'age'}, inplace=True)

# %%
ratings = pd.read_csv('book_rec/Ratings.csv',encoding="latin-1")

# %%
ratings.rename(columns={'User-ID':'id','ISBN':'isbn','Book-Rating':'rating'}, inplace=True)

# %%
ratings
# Out:
#              id         isbn  rating
# 0        276725   034545104X       0
# 1        276726   0155061224       5
# 2        276727   0446520802       0
# 3        276729   052165615X       3
# 4        276729   0521795028       6
# ...         ...          ...     ...
# 1149775  276704   1563526298       9
# 1149776  276706   0679447156       0
# 1149777  276709   0515107662      10
# 1149778  276721   0590442449      10
# 1149779  276723  05162443314       8
#
# [1149780 rows x 3 columns]

# %%
users['age'].isna().sum()
users
# Out:
#             id                            location   age
# 0            1                  nyc, new york, usa   NaN
# 1            2           stockton, california, usa  18.0
# 2            3     moscow, yukon territory, russia   NaN
# 3            4           porto, v.n.gaia, portugal  17.0
# 4            5  farnborough, hants, united kingdom   NaN
# ...        ...                                 ...   ...
# 278853  278854               portland, oregon, usa   NaN
# 278854  278855  tacoma, washington, united kingdom  50.0
# 278855  278856           brampton, ontario, canada   NaN
# 278856  278857           knoxville, tennessee, usa   NaN
# 278857  278858                dublin, n/a, ireland   NaN
#
# [278858 rows x 3 columns]

# %%
mask = ratings['id'].value_counts()>200

# %%
mask_index = mask[mask].index

# %%
mask[mask]
# Out:
# id
# 11676     True
# 198711    True
# 153662    True
# 98391     True
# 35859     True
#           ...
# 274808    True
# 28634     True
# 59727     True
# 268622    True
# 188951    True
# Name: count, Length: 899, dtype: bool

# %%
mask_index
# Out:
# Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352, 110973,
#        235105,
#        ...
#        260183,  73681,  44296, 155916,   9856, 274808,  28634,  59727, 268622,
#        188951],
#       dtype='int64', name='id', length=899)

# %%
ratings = ratings[ratings['id'].isin(mask_index)]

# %%
ratings.shape
# Out:
# (526356, 3)

# %%
ratings
# Out:
#              id        isbn  rating
# 1456     277427  002542730X      10
# 1457     277427  0026217457       0
# 1458     277427  003008685X       8
# 1459     277427  0030615321       0
# 1460     277427  0060002050       0
# ...         ...         ...     ...
# 1147612  275970  3829021860       0
# 1147613  275970  4770019572       0
# 1147614  275970   896086097       0
# 1147615  275970  9626340762       8
# 1147616  275970  9626344990       0
#
# [526356 rows x 3 columns]

# %%
rating = pd.merge(ratings, books, on='isbn', how='inner')

# %%
ratings.groupby('title')
# Out:
#                                                     title  rating
# 0        A Light in the Storm: The Civil War Diary of ...       2
# 1                                   Always Have Popsicles       1
# 2                    Apple Magic (The Collector's series)       1
# 3        Beyond IBM: Leadership Marketing and Finance ...       1
# 4        Clifford Visita El Hospital (Clifford El Gran...       1
# ...                                                   ...     ...
# 160264  Ã?Ã?ber die Pflicht zum Ungehorsam gegen den...       3
# 160265                                    Ã?Ã?lpiraten.       1
# 160266                   Ã?Ã?rger mit Produkt X. Roman.       1
# 160267                            Ã?Ã?stlich der Berge.       1
# 160268                                Ã?Ã?thique en toc       1
#
# [160269 rows x 2 columns]

# %%
rating
# Out:
#             id        isbn  rating  \
# 0       277427  002542730X      10
# 1       277427  0026217457       0
# 2       277427  003008685X       8
# 3       277427  0030615321       0
# 4       277427  0060002050       0
# ...        ...         ...     ...
# 487666  275970  1931868123       0
# 487667  275970  3411086211      10
# 487668  275970  3829021860       0
# 487669  275970  4770019572       0
# 487670  275970  9626340762       8
#
#                                                     title  \
# 0       Politically Correct Bedtime Stories: Modern Ta...
# 1                      Vegetarian Times Complete Cookbook
# 2                                                Pioneers
# 3        Ask for May, Settle for June (A Doonesbury book)
# 4                       On a Wicked Dawn (Cynster Novels)
# ...                                                   ...
# 487666  There's a Porcupine in My Outhouse: Misadventu...
# 487667                                         Die Biene.
# ...

# %%
rating_per_book = rating.groupby('title')['rating'].count().reset_index()
rating_per_book.rename(columns={'rating':'ratings_per_book'}, inplace=True)

# %%
final_rating = pd.merge(rating, rating_per_book, on='title')

# %%
final_rating = final_rating[final_rating['ratings_per_book'] >= 30]

# %%
final_rating
# Out:
#             id        isbn  rating  \
# 0       277427  002542730X      10
# 7       277427  0060177721       0
# 12      277427  006092988X       0
# 13      277427  0060930535       0
# 15      277427  0060934417       0
# ...        ...         ...     ...
# 487534  275970  1558744606       0
# 487578  275970  1573227951       0
# 487579  275970  1573229725       0
# 487618  275970  1586210661       9
# 487619  275970  1586212230       0
#
#                                                     title              author  \
# 0       Politically Correct Bedtime Stories: Modern Ta...   James Finn Garner
# 7                                            Finding Moon      Tony Hillerman
# 12                               A Tree Grows in Brooklyn         Betty Smith
# 13                          The Poisonwood Bible: A Novel  Barbara Kingsolver
# 15                                     Bel Canto: A Novel        Ann Patchett
# ...

# %%
final_rating.drop_duplicates(['id','title'], inplace=True)

# %%
final_pivot = final_rating.pivot_table(columns='id', index='title', values='rating')

# %%
final_pivot.fillna(0.0, inplace=True)

# %%
from scipy.sparse import csr_matrix

# %%
book_sparse = csr_matrix(final_pivot)

# %%
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(algorithm = 'brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distances, suggestions = model.kneighbors(final_pivot.iloc[556,:].values.reshape(1,-1), n_neighbors=6)

# %%
final_pivot.index.get_loc("Harry Potter and the Chamber of Secrets (Book 2)")
# Out:
# 556

# %%
for i in range(len(suggestions)):
    print(final_pivot.index[suggestions[i]])
# Out:
# Index(['Harry Potter and the Chamber of Secrets (Book 2)',
#        'Harry Potter and the Goblet of Fire (Book 4)',
#        'Harry Potter and the Prisoner of Azkaban (Book 3)',
#        'Harry Potter and the Sorcerer's Stone (Book 1)',
#        'The Mammoth Hunters (Auel, Jean M. , Earth's Children.)',
#        'Dinner at the Homesick Restaurant'],
#       dtype='object', name='title')

# %%
final_pivot.iloc[556]
# Out:
# id
# 254       9.0
# 2276      0.0
# 2766      0.0
# 2977      0.0
# 3363      0.0
#          ...
# 275970    9.0
# 277427    0.0
# 277478    0.0
# 277639    0.0
# 278418    0.0
# Name: Harry Potter and the Chamber of Secrets (Book 2), Length: 893, dtype: float64
